# %% [markdown]
# ## Good Python Resources Online?

# %% [markdown]
# #### Youtube
#
# Sentdex youtube channel https://www.youtube.com/user/sentdex/playlists
#
# Pycon
#
# Pycon 2019 https://www.youtube.com/channel/UCxs2IIVXaEHHA4BtTiWZ2mQ
#
# Pycon 2018 https://www.youtube.com/channel/UCsX05-2sVSH7Nx3zuk3NYuQ
#
# Pycon 20xy ...
#
# #### Good Online Courses
# DataCamp: https://datacamp.com
#
# LinkedIn Learning:
# * Advanced Python: https://www.linkedin.com/learning/advanced-python
# * Python 3 Standard Library https://www.linkedin.com/learning/learning-the-python-3-standard-library
#
# #### Good Portals/Communites to follow
#
# RealPython: https://realpython.com/
#
# #### Official Python Documentation
#
# https://docs.python.org/3/index.html
#
# #### Books
#
# Automate the boring stuff: https://automatetheboringstuff.com/
#
# Modern Python Standard Library Cookbook: https://www.packtpub.com/application-development/modern-python-standard-library-cookbook
#
# #### Python Podcasts
#
# Talk Python To Me: https://talkpython.fm/
#
# Python Bytes: https://pythonbytes.fm/

# %% [markdown]
# #### Local Community
#
# Budapest.py https://www.meetup.com/budapest-py/
#
# PyData Budapest: https://www.meetup.com/PyData-Budapest/

# %% [markdown]
# ### Where Can You Go From Here?
#
# ![image.png](attachment:image.png)
#
# * General Programming / Automation
#
#  -> excel, powerpoint and pdf automation: https://www.youtube.com/watch?v=azbOfFipzws
#
#  -> blender: https://www.youtube.com/watch?v=rHzf3Dku_cE and https://www.youtube.com/watch?v=KI0tjZUkb5A
#
#  -> anything with PyAutoGui: https://www.youtube.com/watch?v=1RE5tSPO2RI
# * Data Science with Python
#
#  -> https://www.youtube.com/watch?v=mkv5mxYu0Wk
# * Machine Learning with Python
#
#  -> https://www.youtube.com/watch?v=cKxRvEZd3Mw
# * IoT Hobby Electronics with Python (raspberry pi, rpi)
#
#  -> https://www.raspberrypi.org/
#
#  -> https://pimylifeup.com/category/projects/
